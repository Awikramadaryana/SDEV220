# %% [markdown]
# Write a Python app that will accept student names and GPAs and test if the student qualifies for either the Dean's List or the Honor Roll. Your app will:
# - ask for and accept a student's last name.
# - quit processing student records if the last name entered is 'ZZZ'.
# - ask for and accept a student's first name.
# - ask for and accept the student's GPA as a float.
# - test if the student's GPA is 3.5 or greater and, if so, print a message
# - saying that the student has made the Dean's List.
# - test if the student's GPA is 3.25 or greater and, if so, print a message
# -  saying that the studnet has made the Honor Roll.

# %% [markdown]
# Headers

# %%
### DHV System (Dean and Honors Verification System)
### Ardhika Wikramadaryana
### This system is intended to take user input as student name and gpa to verify 
### qualification for a student to be on the Dean's List or Honor Roll

# %% [markdown]
# Initial User prompting

# %%
print("----------Hello, and welcome to the Dean's List and Honor Roll verification sytem (DHV System)----------")
# Out:
# ----------Hello, and welcome to the Dean's List and Honor Roll verification sytem (DHV System)----------

# %% [markdown]
# User Inputs

# %%
Last_Name = input("Please enter your last name:")
print("----- Enter 'ZZZ' to exit program -----")

if Last_Name == str("ZZZ") or str("zzz"):
    print("Thank you for using our system!")
else:
    First_Name = input("Please enter your first name")
    GPA = float(input("Please enter your GPA"))

    print("Hello " + First_Name + " " + Last_Name)
    if GPA >= 3.5:
        print("Congratulations! You have qualified to be on the Dean's List")
    elif GPA >= 3.25:
        print("Congratulations! You have qualified to be on the Honor Roll")
    else:
        print("Unfortunately you do not qualify at this time")
# Out:
# ----- Enter 'ZZZ' to exit program -----
# Thank you for using our system!

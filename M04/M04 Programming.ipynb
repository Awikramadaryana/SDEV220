# %% [markdown]
# 11.1 Create a file called zoo.py. In it, define a function called hours() that prints the string 'Open 9-5 daily'. Then, use the interactive interpreter to import the zoo module and call its hours() function.

# %%
def hours():
    return "Open 9-5 daily"

# %% [markdown]
# 11.2 In the interactive interpreter, import the zoo module as menagerie and call its hours() function.

# %%
print(hours())
# Out:
# Open 9-5 daily

# %% [markdown]
# Use the sqlalchemy module to connect to the sqlite3 database books.db that you just made in exercise 16.4. As in 16.6, select and print the title column from the book table in alphabetical order.

# %%
import sqlalchemy as sqa

con = sqa.create_engine('sqlite:///books.db')
col = con.execute('SELECT title FROM books')

for i in col:
    print(i)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 4
#       1 import sqlalchemy as sqa
#       3 con = sqa.create_engine('sqlite:///books.db')
# ----> 4 col = con.execute()
#       6 for i in col:
#       7     print(i)
#
# AttributeError: 'Engine' object has no attribute 'execute'

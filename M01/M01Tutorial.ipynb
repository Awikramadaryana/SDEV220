# %%
print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# This is a demonstration of Jupyter notebook. Above is a simple function intended to print the text "Hello World". My SDEV 220 repository has also been connected with my Visual Studio code.
